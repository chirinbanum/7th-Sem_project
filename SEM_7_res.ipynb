# %%
import matplotlib.pyplot as plt
import pandas as pd

# Your model results with Accuracy, F1-Score, Recall
results = {
    "Model": [
        "VAE + MLP",
        "VAE + CNN",
        "DAE + MLP",
        "DAE + CNN",
        "Random Forest",
        "CNN Classifier"
    ],
    "Accuracy": [
        0.8803,
        0.8662,
        0.9225,
        0.8859,
        0.8587,
        0.8908
    ],
    "F1-Score": [
        0.8720,
        0.8600,
        0.9180,
        0.8805,
        0.8520,
        0.8850
    ],
    "Recall": [
        0.8705,
        0.8582,
        0.9202,
        0.8821,
        0.8503,
        0.8871
    ]
}

# Create DataFrame
df = pd.DataFrame(results)

# Plot Table
fig, ax = plt.subplots(figsize=(7, 3.5))  # wider size for extra columns
ax.axis("off")

# Create table inside matplotlib
table = ax.table(
    cellText=df.values,
    colLabels=df.columns,
    cellLoc="center",
    loc="center"
)

# Styling
table.auto_set_font_size(False)
table.set_fontsize(9.5)
table.scale(1.2, 1.2)

# Save and Show
plt.tight_layout()
plt.savefig("model_results_table.png", dpi=300, bbox_inches="tight")
plt.show()
